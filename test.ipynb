# %%
pip install langchain_community
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\CHOWDHURYRaju\Desktop\shipment_qna_bot\.venv\Scripts\python.exe: No module named pip

# %%
langchain_community.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 langchain_community.__version__
#
# NameError: name 'langchain_community' is not defined

# %%
from langchain_community.tools import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain_community.tools import *
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
from langchain_community.tools.python.tool import PythonREPLTool

repl = PythonREPLTool()  # Stateful REPL - variables persist
result = repl.invoke("print(2+2)")  # Returns: "4"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain_community.tools.python.tool import PythonREPLTool
#       3 repl = PythonREPLTool()  # Stateful REPL - variables persist
#       4 result = repl.invoke("print(2+2)")  # Returns: "4"
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
import os

all_items = os.listdir('.')
for itm in all_items:
    print(itm)
# Out:
# .env
# .git
# .gitignore
# .pytest_cache
# .venv
# data
# data_temp
# docs
# pyproject.toml
# README.md
# requirements.txt
# src
# test.ipynb
# tests
# uv.lock
